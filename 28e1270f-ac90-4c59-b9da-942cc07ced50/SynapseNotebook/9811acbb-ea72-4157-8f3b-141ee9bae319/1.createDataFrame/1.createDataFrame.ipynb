# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
# spark - object of spark session

type(spark)
# Out:
# StatementMeta(, ce9e9e26-f598-48eb-ba80-e5ba89edfc02, 3, Finished, Available)
# pyspark.sql.session.SparkSession

# %%
# attributes of spark object 

dir(spark)
# Out:
# StatementMeta(, ce9e9e26-f598-48eb-ba80-e5ba89edfc02, 4, Finished, Available)
# ['Builder',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_activeSession',
#  '_conf',
#  '_convert_from_pandas',
#  '_createFromLocal',
#  '_createFromRDD',
#  '_create_dataframe',
#  '_create_from_pandas_with_arrow',
#  '_create_shell_session',
#  '_getActiveSessionOrCreate',
#  '_get_numpy_record_dtype',
#  '_inferSchema',
#  '_inferSchemaFromList',
#  '_instantiatedSession',
#  '_jconf',
#  '_jsc',
#  '_jsparkSession',
#  '_jvm',
#  '_repr_html_',
#  '_sc',
#  'builder',
#  'catalog',
#  'conf',
#  'createDataFrame',
#  'getActiveSession',
#  'newSession',
#  'range',
#  'read',
#  'readStream',
#  'sparkContext',
#  'sql',
#  'stop',
#  'streams',
#  'table',
#  'udf',
#  'version']

# %%
data = [(1,'Maheer'),(2,'Safa')]

schema = ['id','name']

df = spark.createDataFrame(data,schema)
df.show()
# Out:
# StatementMeta(, ce9e9e26-f598-48eb-ba80-e5ba89edfc02, 27, Finished, Available)
# +---+------+
# | id|  name|
# +---+------+
# |  1|Maheer|
# |  2|  Safa|
# +---+------+

# %%
from pyspark.sql.types import *
schema = StructType([StructField(name='id',dataType=IntegerType()),
            StructField(name='name',dataType= StringType())])


type(schema)
# Out:
# StatementMeta(, ce9e9e26-f598-48eb-ba80-e5ba89edfc02, 16, Finished, Available)
# pyspark.sql.types.StructType

# %%
from pyspark.sql.types import *

data = [(123,'Ram'),(234,'Shyam')]

schema = StructType([StructField(name='id',dataType=IntegerType()),
                    StructField(name='name',dataType=StringType())])
df = spark.createDataFrame(data=data,schema=schema)
df.show()
# Out:
# StatementMeta(, ce9e9e26-f598-48eb-ba80-e5ba89edfc02, 23, Finished, Available)
# +---+-----+
# | id| name|
# +---+-----+
# |123|  Ram|
# |234|Shyam|
# +---+-----+

# %%
df.printSchema()
# Out:
# StatementMeta(, ce9e9e26-f598-48eb-ba80-e5ba89edfc02, 24, Finished, Available)
# root
#  |-- id: integer (nullable = true)
#  |-- name: string (nullable = true)

# %%
data = [{'id':1,'name':'Abhinav'},{'id':2,'name':'Safa'}]

df = spark.createDataFrame(data)
df.show()
df.printSchema()
# Out:
# StatementMeta(, ce9e9e26-f598-48eb-ba80-e5ba89edfc02, 30, Finished, Available)
# +---+-------+
# | id|   name|
# +---+-------+
# |  1|Abhinav|
# |  2|   Safa|
# +---+-------+
#
# root
#  |-- id: long (nullable = true)
#  |-- name: string (nullable = true)
